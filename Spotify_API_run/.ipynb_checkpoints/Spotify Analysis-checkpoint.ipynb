# %%
import requests
import base64
import json
import sys
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
# Load the full CSV file created in prior step
music_df = pd.read_csv("output_data/Merged_Music_File_with_Spotify.csv")
music_df.drop(columns="Unnamed: 0", inplace=True)
music_df.drop(columns="Genre", inplace=True)
filtered_music_df = pd.DataFrame(music_df.loc[music_df["Year"] >2017,:])

# Display sample data
filtered_music_df.head()
# Out:
#        Position                 Track Name          Artist  Streams      Date  \
# 72182         1                   rockstar     Post Malone  3962314  1/1/2018
# 72183         2  Havana (feat. Young Thug)  Camila Cabello  3314677  1/1/2018
# 72184         3                  New Rules        Dua Lipa  2940488  1/1/2018
# 72185         4                     Wolves    Selena Gomez  2509878  1/1/2018
# 72186         5               Shape of You      Ed Sheeran  2439876  1/1/2018
#
#        Year  Month Master Genre                Track ID  Popularity  ...  \
# 72182  2018      1          Rap  0e7ipj03S05BNilyu5bRzt          84  ...
# 72183  2018      1          Pop  1rfofaqEpACxVEHIZBJe6W          80  ...
# 72184  2018      1          Pop  2ekn2ttSfGqwhhate0LSR0          81  ...
# 72185  2018      1          Pop  0tBbt8CrmxbjRP0pueQkyU          79  ...
# 72186  2018      1          Pop  7qiZfU4dY1lWllzX7mPBI3          87  ...
#
#        energy  instrumentalness  key  liveness  loudness  mode  speechiness  \
# 72182   0.520          0.000070    5    0.1310    -6.136     0       0.0712
# 72183   0.523          0.000036    2    0.1320    -4.333     1       0.0300
# 72184   0.700          0.000016    9    0.1530    -6.021     0       0.0694
# 72185   0.804          0.000000   11    0.2040    -4.614     0       0.0448
# 72186   0.652          0.000000    1    0.0931    -3.183     0       0.0802
#
#          tempo  time_signature  valence
# 72182  159.801               4    0.129
# 72183  104.988               4    0.394
# 72184  116.073               4    0.608
# 72185  124.987               4    0.306
# 72186   95.977               4    0.931
#
# [5 rows x 23 columns]

# %%
filtered_music_df['Date'] = pd.to_datetime(filtered_music_df['Date'])
filtered_music_df.head(2)
# Out:
#        Position                 Track Name          Artist  Streams  \
# 72182         1                   rockstar     Post Malone  3962314
# 72183         2  Havana (feat. Young Thug)  Camila Cabello  3314677
#
#             Date  Year  Month Master Genre                Track ID  \
# 72182 2018-01-01  2018      1          Rap  0e7ipj03S05BNilyu5bRzt
# 72183 2018-01-01  2018      1          Pop  1rfofaqEpACxVEHIZBJe6W
#
#        Popularity  ...  energy  instrumentalness  key  liveness  loudness  \
# 72182          84  ...   0.520          0.000070    5     0.131    -6.136
# 72183          80  ...   0.523          0.000036    2     0.132    -4.333
#
#        mode  speechiness    tempo  time_signature  valence
# 72182     0       0.0712  159.801               4    0.129
# 72183     1       0.0300  104.988               4    0.394
#
# [2 rows x 23 columns]

# %%
daily_top_song = pd.DataFrame(filtered_music_df.loc[filtered_music_df["Position"]==1,:])
daily_top_song.head()
# Out:
#        Position Track Name       Artist  Streams       Date  Year  Month  \
# 72182         1   rockstar  Post Malone  3962314 2018-01-01  2018      1
# 72382         1   rockstar  Post Malone  4072359 2018-01-02  2018      1
# 72582         1   rockstar  Post Malone  4194625 2018-01-03  2018      1
# 72782         1   rockstar  Post Malone  4168292 2018-01-04  2018      1
# 72982         1   rockstar  Post Malone  4346638 2018-01-05  2018      1
#
#       Master Genre                Track ID  Popularity  ...  energy  \
# 72182          Rap  0e7ipj03S05BNilyu5bRzt          84  ...    0.52
# 72382          Rap  0e7ipj03S05BNilyu5bRzt          84  ...    0.52
# 72582          Rap  0e7ipj03S05BNilyu5bRzt          84  ...    0.52
# 72782          Rap  0e7ipj03S05BNilyu5bRzt          84  ...    0.52
# 72982          Rap  0e7ipj03S05BNilyu5bRzt          84  ...    0.52
#
#        instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 72182           0.00007    5     0.131    -6.136     0       0.0712  159.801
# 72382           0.00007    5     0.131    -6.136     0       0.0712  159.801
# 72582           0.00007    5     0.131    -6.136     0       0.0712  159.801
# 72782           0.00007    5     0.131    -6.136     0       0.0712  159.801
# 72982           0.00007    5     0.131    -6.136     0       0.0712  159.801
#
#        time_signature  valence
# 72182               4    0.129
# 72382               4    0.129
# 72582               4    0.129
# 72782               4    0.129
# 72982               4    0.129
#
# [5 rows x 23 columns]

# %%
#Pre-Covid 1/1/2017 - 3/17/2020
#Post-Covid 3/20/2020 - 2022

# Popularity
# acousticness
# danceability
# duration_ms
# energy
# instrumentalness
# key
# liveness
# loudness 
# mode
# speechiness 
# tempo
# time_signature
# valence

# %%
# loudness 
loudness = filtered_music_df.loc[:, ["Position", "Track Name", "Artist", "Streams",
                                 "Date", "Year", "Month", "Master Genre", 
                                 "Track ID", "Popularity", "loudness"]]
loudness.head()
# Out:
#        Position                 Track Name          Artist  Streams  \
# 72182         1                   rockstar     Post Malone  3962314
# 72183         2  Havana (feat. Young Thug)  Camila Cabello  3314677
# 72184         3                  New Rules        Dua Lipa  2940488
# 72185         4                     Wolves    Selena Gomez  2509878
# 72186         5               Shape of You      Ed Sheeran  2439876
#
#             Date  Year  Month Master Genre                Track ID  \
# 72182 2018-01-01  2018      1          Rap  0e7ipj03S05BNilyu5bRzt
# 72183 2018-01-01  2018      1          Pop  1rfofaqEpACxVEHIZBJe6W
# 72184 2018-01-01  2018      1          Pop  2ekn2ttSfGqwhhate0LSR0
# 72185 2018-01-01  2018      1          Pop  0tBbt8CrmxbjRP0pueQkyU
# 72186 2018-01-01  2018      1          Pop  7qiZfU4dY1lWllzX7mPBI3
#
#        Popularity  loudness
# 72182          84    -6.136
# 72183          80    -4.333
# 72184          81    -6.021
# 72185          79    -4.614
# 72186          87    -3.183

# %%
daily_top_loudness_song = pd.DataFrame(loudness.loc[loudness["Position"]==1,:])
daily_top_loudness_song.head()
# Out:
#        Position Track Name       Artist  Streams       Date  Year  Month  \
# 72182         1   rockstar  Post Malone  3962314 2018-01-01  2018      1
# 72382         1   rockstar  Post Malone  4072359 2018-01-02  2018      1
# 72582         1   rockstar  Post Malone  4194625 2018-01-03  2018      1
# 72782         1   rockstar  Post Malone  4168292 2018-01-04  2018      1
# 72982         1   rockstar  Post Malone  4346638 2018-01-05  2018      1
#
#       Master Genre                Track ID  Popularity  loudness
# 72182          Rap  0e7ipj03S05BNilyu5bRzt          84    -6.136
# 72382          Rap  0e7ipj03S05BNilyu5bRzt          84    -6.136
# 72582          Rap  0e7ipj03S05BNilyu5bRzt          84    -6.136
# 72782          Rap  0e7ipj03S05BNilyu5bRzt          84    -6.136
# 72982          Rap  0e7ipj03S05BNilyu5bRzt          84    -6.136

# %%
# tempo
tempo = filtered_music_df.loc[:, ["Position", "Track Name", "Artist", "Streams",
                              "Date", "Year", "Month", "Master Genre", 
                              "Track ID", "Popularity", "tempo"]]

tempo.head()
# Out:
#        Position                 Track Name          Artist  Streams  \
# 72182         1                   rockstar     Post Malone  3962314
# 72183         2  Havana (feat. Young Thug)  Camila Cabello  3314677
# 72184         3                  New Rules        Dua Lipa  2940488
# 72185         4                     Wolves    Selena Gomez  2509878
# 72186         5               Shape of You      Ed Sheeran  2439876
#
#             Date  Year  Month Master Genre                Track ID  \
# 72182 2018-01-01  2018      1          Rap  0e7ipj03S05BNilyu5bRzt
# 72183 2018-01-01  2018      1          Pop  1rfofaqEpACxVEHIZBJe6W
# 72184 2018-01-01  2018      1          Pop  2ekn2ttSfGqwhhate0LSR0
# 72185 2018-01-01  2018      1          Pop  0tBbt8CrmxbjRP0pueQkyU
# 72186 2018-01-01  2018      1          Pop  7qiZfU4dY1lWllzX7mPBI3
#
#        Popularity    tempo
# 72182          84  159.801
# 72183          80  104.988
# 72184          81  116.073
# 72185          79  124.987
# 72186          87   95.977

# %%
# danceability
danceability = filtered_music_df.loc[:, ["Position", "Track Name", "Artist", "Streams", 
                              "Date", "Year", "Month", "Master Genre", 
                              "Track ID", "Popularity", "danceability"]]

danceability.head()
# Out:
#        Position                 Track Name          Artist  Streams  \
# 72182         1                   rockstar     Post Malone  3962314
# 72183         2  Havana (feat. Young Thug)  Camila Cabello  3314677
# 72184         3                  New Rules        Dua Lipa  2940488
# 72185         4                     Wolves    Selena Gomez  2509878
# 72186         5               Shape of You      Ed Sheeran  2439876
#
#             Date  Year  Month Master Genre                Track ID  \
# 72182 2018-01-01  2018      1          Rap  0e7ipj03S05BNilyu5bRzt
# 72183 2018-01-01  2018      1          Pop  1rfofaqEpACxVEHIZBJe6W
# 72184 2018-01-01  2018      1          Pop  2ekn2ttSfGqwhhate0LSR0
# 72185 2018-01-01  2018      1          Pop  0tBbt8CrmxbjRP0pueQkyU
# 72186 2018-01-01  2018      1          Pop  7qiZfU4dY1lWllzX7mPBI3
#
#        Popularity  danceability
# 72182          84         0.585
# 72183          80         0.765
# 72184          81         0.762
# 72185          79         0.724
# 72186          87         0.825

# %%
daily_top_dance_song = pd.DataFrame(danceability.loc[danceability["Position"]==1,:])
daily_top_dance_song.head()
# Out:
#        Position Track Name       Artist  Streams       Date  Year  Month  \
# 72182         1   rockstar  Post Malone  3962314 2018-01-01  2018      1
# 72382         1   rockstar  Post Malone  4072359 2018-01-02  2018      1
# 72582         1   rockstar  Post Malone  4194625 2018-01-03  2018      1
# 72782         1   rockstar  Post Malone  4168292 2018-01-04  2018      1
# 72982         1   rockstar  Post Malone  4346638 2018-01-05  2018      1
#
#       Master Genre                Track ID  Popularity  danceability
# 72182          Rap  0e7ipj03S05BNilyu5bRzt          84         0.585
# 72382          Rap  0e7ipj03S05BNilyu5bRzt          84         0.585
# 72582          Rap  0e7ipj03S05BNilyu5bRzt          84         0.585
# 72782          Rap  0e7ipj03S05BNilyu5bRzt          84         0.585
# 72982          Rap  0e7ipj03S05BNilyu5bRzt          84         0.585

# %%
dt_danceability = daily_top_dance_song.groupby(["Track Name","Artist"])["danceability"].mean().nlargest(10)
print(dt_danceability)

dt_danceability.plot(kind = 'barh')
plt.title("Top Danceable Songs")
plt.ylabel("Song")
plt.xlabel("Danceability Factor")
# Out:
# Track Name                                      Artist
# The Ringer                                      Eminem              0.939
# WAP (feat. Megan Thee Stallion)                 Cardi B             0.935
# All Mine                                        Kanye West          0.925
# Nonstop                                         Drake               0.912
# I Love It (& Lil Pump)                          Kanye West          0.901
# The Box                                         Roddy Ricch         0.896
# Lucky You (feat. Joyner Lucas)                  Eminem              0.876
# Mona Lisa (feat. Kendrick Lamar)                Lil Wayne           0.856
# This Is America                                 Childish Gambino    0.854
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)  DJ Snake            0.842
# Name: danceability, dtype: float64
# Text(0.5, 0, 'Danceability Factor')

# %%
# speechiness 
speechiness = filtered_music_df.loc[:, ["Position", "Track Name", "Artist", "Streams", 
                              "Date", "Year", "Month", "Master Genre", 
                              "Track ID", "Popularity", "speechiness"]]

speechiness.head()
# Out:
#        Position                 Track Name          Artist  Streams  \
# 72182         1                   rockstar     Post Malone  3962314
# 72183         2  Havana (feat. Young Thug)  Camila Cabello  3314677
# 72184         3                  New Rules        Dua Lipa  2940488
# 72185         4                     Wolves    Selena Gomez  2509878
# 72186         5               Shape of You      Ed Sheeran  2439876
#
#             Date  Year  Month Master Genre                Track ID  \
# 72182 2018-01-01  2018      1          Rap  0e7ipj03S05BNilyu5bRzt
# 72183 2018-01-01  2018      1          Pop  1rfofaqEpACxVEHIZBJe6W
# 72184 2018-01-01  2018      1          Pop  2ekn2ttSfGqwhhate0LSR0
# 72185 2018-01-01  2018      1          Pop  0tBbt8CrmxbjRP0pueQkyU
# 72186 2018-01-01  2018      1          Pop  7qiZfU4dY1lWllzX7mPBI3
#
#        Popularity  speechiness
# 72182          84       0.0712
# 72183          80       0.0300
# 72184          81       0.0694
# 72185          79       0.0448
# 72186          87       0.0802

# %%
# energy
energy = filtered_music_df.loc[:, ["Position", "Track Name", "Artist", "Streams", 
                              "Date", "Year", "Month", "Master Genre", 
                              "Track ID", "Popularity", "energy"]]

energy.head()
# Out:
#        Position                 Track Name          Artist  Streams  \
# 72182         1                   rockstar     Post Malone  3962314
# 72183         2  Havana (feat. Young Thug)  Camila Cabello  3314677
# 72184         3                  New Rules        Dua Lipa  2940488
# 72185         4                     Wolves    Selena Gomez  2509878
# 72186         5               Shape of You      Ed Sheeran  2439876
#
#             Date  Year  Month Master Genre                Track ID  \
# 72182 2018-01-01  2018      1          Rap  0e7ipj03S05BNilyu5bRzt
# 72183 2018-01-01  2018      1          Pop  1rfofaqEpACxVEHIZBJe6W
# 72184 2018-01-01  2018      1          Pop  2ekn2ttSfGqwhhate0LSR0
# 72185 2018-01-01  2018      1          Pop  0tBbt8CrmxbjRP0pueQkyU
# 72186 2018-01-01  2018      1          Pop  7qiZfU4dY1lWllzX7mPBI3
#
#        Popularity  energy
# 72182          84   0.520
# 72183          80   0.523
# 72184          81   0.700
# 72185          79   0.804
# 72186          87   0.652

# %%
# valence
valence = filtered_music_df.loc[:, ["Position", "Track Name", "Artist", "Streams", 
                              "Date", "Year", "Month", "Master Genre", 
                              "Track ID", "Popularity", "valence"]]

valence.head()
# Out:
#        Position                 Track Name          Artist  Streams  \
# 72182         1                   rockstar     Post Malone  3962314
# 72183         2  Havana (feat. Young Thug)  Camila Cabello  3314677
# 72184         3                  New Rules        Dua Lipa  2940488
# 72185         4                     Wolves    Selena Gomez  2509878
# 72186         5               Shape of You      Ed Sheeran  2439876
#
#             Date  Year  Month Master Genre                Track ID  \
# 72182 2018-01-01  2018      1          Rap  0e7ipj03S05BNilyu5bRzt
# 72183 2018-01-01  2018      1          Pop  1rfofaqEpACxVEHIZBJe6W
# 72184 2018-01-01  2018      1          Pop  2ekn2ttSfGqwhhate0LSR0
# 72185 2018-01-01  2018      1          Pop  0tBbt8CrmxbjRP0pueQkyU
# 72186 2018-01-01  2018      1          Pop  7qiZfU4dY1lWllzX7mPBI3
#
#        Popularity  valence
# 72182          84    0.129
# 72183          80    0.394
# 72184          81    0.608
# 72185          79    0.306
# 72186          87    0.931

# %%
# Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), 
# while tracks with low valence sound more negative (e.g. sad, depressed, angry).

valence['Sentiment'] = valence['valence'].map(lambda x:'Sad' if x<0.4 else 'Happy')
valence.head()
# Out:
#        Position                 Track Name          Artist  Streams  \
# 72182         1                   rockstar     Post Malone  3962314
# 72183         2  Havana (feat. Young Thug)  Camila Cabello  3314677
# 72184         3                  New Rules        Dua Lipa  2940488
# 72185         4                     Wolves    Selena Gomez  2509878
# 72186         5               Shape of You      Ed Sheeran  2439876
#
#             Date  Year  Month Master Genre                Track ID  \
# 72182 2018-01-01  2018      1          Rap  0e7ipj03S05BNilyu5bRzt
# 72183 2018-01-01  2018      1          Pop  1rfofaqEpACxVEHIZBJe6W
# 72184 2018-01-01  2018      1          Pop  2ekn2ttSfGqwhhate0LSR0
# 72185 2018-01-01  2018      1          Pop  0tBbt8CrmxbjRP0pueQkyU
# 72186 2018-01-01  2018      1          Pop  7qiZfU4dY1lWllzX7mPBI3
#
#        Popularity  valence Sentiment
# 72182          84    0.129       Sad
# 72183          80    0.394       Sad
# 72184          81    0.608     Happy
# 72185          79    0.306       Sad
# 72186          87    0.931     Happy

# %%
# Pre Covid dataframe (using a 486 day time frame to match the "post" covid data we have)
pre_valence = valence.loc[(valence["Date"] > "2018-11-16")
                          & (valence["Date"] < "2020-03-18")]

# Count streams for songs by sentiment 
prev_streams = pre_valence.groupby(['Sentiment'])['Streams'].sum()

# Title for Pie Chart
print("Streams (%) of Sad/Happy songs before Lockdown")

# Plot Pie Chart
label = ['Happy', 'Sad']
explode = (0.0, 0.0) 
plt.pie(prev_streams, labels = label, explode = explode, autopct='%.1f%%', radius = 1, startangle=135)
plt.show()


# Post Covid dataframe
post_valence = valence.loc[valence["Date"] > "2020-03-17"]

# Count streams for songs by sentiment 
post_streams = post_valence.groupby(['Sentiment'])['Streams'].sum()

# Title for Pie Chart
print("Streams (%) of Sad/Happy songs during/after Lockdown")

# Plot Pie Chart
label = ['Happy', 'Sad']
explode = (0.0, 0.0) 
plt.pie(post_streams, labels = label, explode = explode, autopct='%.1f%%', radius = 1, startangle=135)
plt.show()
# Out:
# Streams (%) of Sad/Happy songs before Lockdown
# Streams (%) of Sad/Happy songs during/after Lockdown
