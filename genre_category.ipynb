# %%
#Spotify Analysis by Categories/Genres and Years
# Read existing file created from the API call and perform the analysis

# %%
#read the csv
# Dependencies
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
# Store filepath in a variable
file_music = Path("Music_Data.csv")
music_data_df = pd.read_csv(file_music, encoding="ISO-8859-1")

# %%
# Show the first five rows.
music_data_df.head()
# Out:
#    Position                               Track Name            Artist  \
# 0         1                                  Starboy        The Weeknd
# 1         2                                   Closer  The Chainsmokers
# 2         3                          Let Me Love You          DJ Snake
# 3         4  Rockabye (feat. Sean Paul & Anne-Marie)      Clean Bandit
# 4         5                                One Dance             Drake
#
#    Streams      Date  Year  Month  \
# 0  3135625  1/1/2017  2017      1
# 1  3015525  1/1/2017  2017      1
# 2  2545384  1/1/2017  2017      1
# 3  2356604  1/1/2017  2017      1
# 4  2259887  1/1/2017  2017      1
#
#                                                Genre Master Genre
# 0     canadian pop - canadian contemporary r&b - pop          Pop
# 1  pop - pop dance - tropical house - edm - elect...          Pop
# 2  pop - electronic trap - dance pop - edm - pop ...          Pop
# 3  pop - uk dance - dance pop - uk funky - tropic...          Pop
# 4  toronto rap - canadian pop - canadian hip hop ...      Hip-Hop

# %%
# Plot data Genre Summary by Streams

summary_agg = music_data_df.groupby("Master Genre").agg({"Streams":["mean","median","var","std","sem"]})
summary_agg
# Out:
#                    Streams                                         \
#                       mean     median           var           std
# Master Genre
# Christian     7.603444e+05   777725.0  2.955462e+10  1.719146e+05
# Country       9.347300e+05   835656.5  2.257796e+11  4.751627e+05
# EDM           1.152792e+06   947146.0  3.487957e+11  5.905893e+05
# Folk          1.091498e+06   926083.0  3.978592e+11  6.307608e+05
# Hip-Hop       1.176062e+06   855024.0  8.220077e+11  9.066464e+05
# Hollywood     8.085993e+05   701606.0  1.118029e+11  3.343694e+05
# Jazz          1.506183e+06  1150318.5  1.289791e+12  1.135690e+06
# Latin         1.174371e+06   931892.0  5.507062e+11  7.420958e+05
# Novelty       1.029599e+06  1030785.0  6.593809e+10  2.567841e+05
# Other         8.686635e+05   727945.5  2.208420e+11  4.699383e+05
# Pop           1.225268e+06   905548.0  7.989352e+11  8.938318e+05
# R&B & Soul    1.040350e+06   820829.5  6.007789e+11  7.750993e+05
# Rap           1.201069e+06   909686.0  6.742889e+11  8.211510e+05
# Regional      1.157206e+06   922645.0  4.566408e+11  6.757520e+05
# Rock          8.845262e+05   766139.0  2.216201e+11  4.707655e+05
#
#
#                        sem
# Master Genre
# Christian     76882.529446
# Country       13428.891440
# EDM            5820.944774
# Folk          49866.017783
# Hip-Hop        4877.334001
# Hollywood     10780.503668
# Jazz          30287.752567
# Latin          3779.126836
# Novelty       24595.459357
# Other         12190.777900
# Pop            2311.882151
# R&B & Soul    10632.773310
# Rap            3336.964523
# Regional       8342.617511
# Rock           4597.485800

# %%
#Split the master data by Year

summary_year_2017 = pd.DataFrame(music_data_df[music_data_df['Date'].str[-4:]=='2017'])
summary_year_2018 = pd.DataFrame(music_data_df.loc[music_data_df['Date'].str[-4:]=='2018'])
summary_year_2019 = pd.DataFrame(music_data_df.loc[music_data_df['Date'].str[-4:]=='2019'])
summary_year_2020 = pd.DataFrame(music_data_df.loc[music_data_df['Date'].str[-4:]=='2020'])
summary_year_2021 = pd.DataFrame(music_data_df.loc[music_data_df['Date'].str[-4:]=='2021'])

summary_agg_year_2017 = summary_year_2017.groupby(["Master Genre", "Year"  ])["Streams"].aggregate('count')

summary_agg_year_2017 
# Plot aggreagate for various years 2017 - 2021 using above data filtered by year

fig = plt.figure(figsize = (15, 10))
summary_agg_year_2017.plot(kind='bar')

plt.title('Total Number of Streams by Genre and Year = 2017')
plt.xlabel("Genre")
plt.ylabel('Streams')
plt.xticks(rotation=90)
plt.show()

#2017

# %%
summary_agg_year_2018 = summary_year_2018.groupby(["Master Genre", "Year"  ])["Streams"].aggregate('count')

summary_agg_year_2018 


fig = plt.figure(figsize = (15, 10))
summary_agg_year_2018.plot(kind='bar')

plt.title('Total Number of Streams by Genre and Year = 2018')
plt.xlabel("Genre")
plt.ylabel('Streams')
plt.xticks(rotation=90)
plt.show()

#2018

# %%
summary_agg_year_2019 = summary_year_2019.groupby(["Master Genre", "Year"  ])["Streams"].aggregate('count')

summary_agg_year_2019 


fig = plt.figure(figsize = (15, 10))
summary_agg_year_2019.plot(kind='bar')
#plt.bar(summary_agg_year_2017["Master Genre"],summary_agg_year_2017["Streams"], align ="center")
plt.title('Total Number of Streams by Genre and Year = 2019')
plt.xlabel("Genre")
plt.ylabel('Streams')
plt.xticks(rotation=90)
plt.show()

#2019

# %%
summary_agg_year_2020 = summary_year_2020.groupby(["Master Genre", "Year"  ])["Streams"].aggregate('count')

summary_agg_year_2020 


fig = plt.figure(figsize = (15, 10))
summary_agg_year_2020.plot(kind='bar')
#plt.bar(summary_agg_year_2017["Master Genre"],summary_agg_year_2017["Streams"], align ="center")
plt.title('Total Number of Streams by Genre and Year = 2020')
plt.xlabel("Genre")
plt.ylabel('Streams')
plt.xticks(rotation=90)
plt.show()

#2020

# %%
summary_agg_year_2021 = summary_year_2021.groupby(["Master Genre", "Year"  ])["Streams"].aggregate('count')

summary_agg_year_2021 


fig = plt.figure(figsize = (15, 10))
summary_agg_year_2021.plot(kind='bar')
#plt.bar(summary_agg_year_2017["Master Genre"],summary_agg_year_2017["Streams"], align ="center")
plt.title('Total Number of Streams by Genre and Year = 2021')
plt.xlabel("Genre")
plt.ylabel('Streams')
plt.xticks(rotation=90)
plt.show()

#2021

# %%
#Streams by Genre for all years 2017-2021. Streams are in large numbers and scaled down

fig = plt.figure(figsize = (10, 6))
plt.bar(music_data_df["Master Genre"],music_data_df["Streams"], align ="center")
plt.title('Total Number of Streams by Genre - All years')
plt.xlabel("Genre")
plt.ylabel('Streams')
plt.xticks(rotation=90)
plt.show()

# %%
#Top Genre in all years

color = ['lightblue', 'blue', 'purple', 'red', 'black','yellow', 'orange','pink']

summary_agg_genre = music_data_df['Master Genre'].value_counts()
summary_agg_genre.plot(kind='bar', color = color)
plt.title('Top Genre - all years')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()

# %%
#Filter by Single artist and show streams for all years

summary_artist = pd.DataFrame(music_data_df[music_data_df['Artist'] == 'Taylor Swift'])
summary_artist_2017 = pd.DataFrame(summary_artist[summary_artist['Date'].str[-4:]=='2017'])
summary_artist_2018 = pd.DataFrame(summary_artist[summary_artist['Date'].str[-4:]=='2018'])
summary_artist_2019 = pd.DataFrame(summary_artist[summary_artist['Date'].str[-4:]=='2019'])
summary_artist_2020 = pd.DataFrame(summary_artist[summary_artist['Date'].str[-4:]=='2020'])
summary_artist_2021 = pd.DataFrame(summary_artist[summary_artist['Date'].str[-4:]=='2021'])
summary_artist_2021
# Out:
#         Position                                         Track Name  \
# 290214        33                                             willow
# 290347       166                                 champagne problems
# 290403        22                                             willow
# 290495       114                                 champagne problems
# 290546       165                     no body, no crime (feat. HAIM)
# ...          ...                                                ...
# 315144       163  Mr. Perfectly Fine (Taylorâs Version) (From ...
# 315362       181  Mr. Perfectly Fine (Taylorâs Version) (From ...
# 316164       183  Mr. Perfectly Fine (Taylorâs Version) (From ...
# 316376       195  Mr. Perfectly Fine (Taylorâs Version) (From ...
# 316770       189  Mr. Perfectly Fine (Taylorâs Version) (From ...
#
#               Artist  Streams       Date  Year  Month                Genre  \
# 290214  Taylor Swift  1605305   1/1/2021  2021      1  pop - post-teen pop
# 290347  Taylor Swift   761893   1/1/2021  2021      1  pop - post-teen pop
# 290403  Taylor Swift  1826995   1/2/2021  2021      1  pop - post-teen pop
# 290495  Taylor Swift   855099   1/2/2021  2021      1  pop - post-teen pop
# 290546  Taylor Swift   683337   1/2/2021  2021      1  pop - post-teen pop
# ...              ...      ...        ...   ...    ...                  ...
# 315144  Taylor Swift   768039   5/5/2021  2021      5  pop - post-teen pop
# 315362  Taylor Swift   755693   5/6/2021  2021      5  pop - post-teen pop
# 316164  Taylor Swift   704936  5/10/2021  2021      5  pop - post-teen pop
# 316376  Taylor Swift   706071  5/11/2021  2021      5  pop - post-teen pop
# 316770  Taylor Swift   732476  5/13/2021  2021      5  pop - post-teen pop
#
#        Master Genre
# 290214          Pop
# 290347          Pop
# 290403          Pop
# 290495          Pop
# 290546          Pop
# ...             ...
# 315144          Pop
# 315362          Pop
# 316164          Pop
# 316376          Pop
# 316770          Pop
#
# [319 rows x 9 columns]

# %%
#Create Line plot for artist

summary_artist.groupby('Year')['Streams'].sum().plot(legend=True)
plt.xlabel('Year')
plt.ylabel('Taylor Swift Streams')
# Out:
# Text(0, 0.5, 'Taylor Swift Streams')

# %%
taylor_bar=summary_artist.groupby('Year')['Streams'].sum()
plt.xlabel('Year')
plt.ylabel('Streams')
taylor_bar.plot(kind='bar')
# Out:
# <Axes: xlabel='Year', ylabel='Streams'>

# %%
#Get top 5 artists for all years
summary_agg_artist = pd.DataFrame(music_data_df.groupby(['Artist'])['Streams'].aggregate('count'))

summary_agg_artist.sort_values(by=['Streams'], ascending=False)
# Out:
#                   Streams
# Artist
# Ed Sheeran           9461
# Post Malone          9172
# XXXTENTACION         6569
# Billie Eilish        6499
# Drake                6496
# ...                   ...
# Snow Patrol             1
# Stephanie Poetri        1
# Dream                   1
# Disclosure              1
# SiR                     1
#
# [1126 rows x 1 columns]

# %%
#Top 5 artists

summary_agg_artist_new = pd.DataFrame(summary_agg_artist.loc[summary_agg_artist['Streams'] >= 6496])
summary_agg_artist_new.sort_values(by=['Streams'], ascending=False)
summary_agg_artist_new
# Out:
#                Streams
# Artist
# Billie Eilish     6499
# Drake             6496
# Ed Sheeran        9461
# Post Malone       9172
# XXXTENTACION      6569

# %%
summary_agg_artist_new_index = summary_agg_artist_new.copy()
summary_agg_artist_new_index.reset_index(inplace=True)
summary_agg_artist_new_index
# Out:
#           Artist  Streams
# 0  Billie Eilish     6499
# 1          Drake     6496
# 2     Ed Sheeran     9461
# 3    Post Malone     9172
# 4   XXXTENTACION     6569

# %%
#Percentage of artists streams across all years
labels = summary_agg_artist_new_index['Artist']


colors = ['Orange','Blue','Green','Red','Pink']
explode = (0,0,0.05,0,0)
x=summary_agg_artist_new_index['Streams']
plt.pie(x=x, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=False)
plt.show()

# %%
summary_agg_artist_new_index
# Out:
#           Artist  Streams
# 0  Billie Eilish     6499
# 1          Drake     6496
# 2     Ed Sheeran     9461
# 3    Post Malone     9172
# 4   XXXTENTACION     6569

# %%
#summary_agg_artist_new_index.plot(kind='pie',  y='Streams', figsize=(8, 8))

# %%
#Summary across all years Slight Spike is seen for 2020 during covid
summary_agg_streams = music_data_df.groupby(["Year"])["Streams"].aggregate('count')


fig = plt.figure(figsize = (10, 6))
plt.bar(music_data_df["Year"],music_data_df["Streams"], align ="center")
plt.title('Total Number of Streams by Year')
plt.xlabel("Year")
plt.ylabel('Streams')
plt.xticks(rotation=90)
plt.show()
